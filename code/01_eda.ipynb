# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nadyinky/sephora-products-and-skincare-reviews")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/destinyogu/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2

# %%
import os

path = "/Users/destinyogu/.cache/kagglehub/datasets/nadyinky/sephora-products-and-skincare-reviews/versions/2"
path_list = os.listdir(path)
path_list
# Out:
# ['product_info.csv',
#  'reviews_0-250.csv',
#  'reviews_1250-end.csv',
#  'reviews_750-1250.csv',
#  'reviews_250-500.csv',
#  'reviews_500-750.csv']

# %%
import pandas as pd

# products = pd.read_csv(f"{path}/product_info.csv")
# reviews = pd.read_csv(f"{path}/reviews.csv")

# products_ = path_list[0]
# reviews_path = path_list[1:]
# for path in path_list:



products_path = os.path.join(path, 'product_info.csv')
r_path_1 = os.path.join(path, "reviews_0-250.csv")
r_path_2 = os.path.join(path, "reviews_250-500.csv")
r_path_3 = os.path.join(path, "reviews_250-500.csv")
r_path_4 = os.path.join(path, "reviews_750-1250.csv")
r_path_5 = os.path.join(path, "reviews_1250-end.csv")


products = pd.read_csv(products_path)
reviews_1 = pd.read_csv(r_path_1, index_col=0)
reviews_2 = pd.read_csv(r_path_2, index_col=0)
reviews_3 = pd.read_csv(r_path_3, index_col=0)
reviews_4 = pd.read_csv(r_path_4, index_col=0)
reviews_5 = pd.read_csv(r_path_5, index_col=0)
# Out:
# /var/folders/z0/pslqf_691f94wn6r6l2rvjgm0000gn/T/ipykernel_9078/2499718909.py:21: DtypeWarning: Columns (0: rating) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_1 = pd.read_csv(r_path_1, index_col=0)
# /var/folders/z0/pslqf_691f94wn6r6l2rvjgm0000gn/T/ipykernel_9078/2499718909.py:24: DtypeWarning: Columns (0: rating) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_4 = pd.read_csv(r_path_4, index_col=0)
# /var/folders/z0/pslqf_691f94wn6r6l2rvjgm0000gn/T/ipykernel_9078/2499718909.py:25: DtypeWarning: Columns (0: rating) have mixed types. Specify dtype option on import or set low_memory=False.
#   reviews_5 = pd.read_csv(r_path_5, index_col=0)

# %%
print(products.shape)
products
# Out:
# (8494, 27)
#      product_id                                       product_name  brand_id  \
# 0       P473671                            Fragrance Discovery Set      6342
# 1       P473668                            La Habana Eau de Parfum      6342
# 2       P473662                          Rainbow Bar Eau de Parfum      6342
# 3       P473660                               Kasbah Eau de Parfum      6342
# 4       P473658                          Purple Haze Eau de Parfum      6342
# ...         ...                                                ...       ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette      1070
# 8490    P500874                              L'Homme Eau de Parfum      1070
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set      1070
# 8492    P504448                           Y Eau de Parfum Gift Set      1070
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...      1070
#
# ...

# %%
reviews = pd.concat([reviews_1, reviews_2, reviews_3, reviews_4, reviews_5])
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1184874 entries, 0 to 49976
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   author_id                 1184874 non-null  object
#  1   rating                    1184874 non-null  int64
#  2   is_recommended            1002703 non-null  float64
#  3   helpfulness               571832 non-null   float64
#  4   total_feedback_count      1184874 non-null  int64
#  5   total_neg_feedback_count  1184874 non-null  int64
#  6   total_pos_feedback_count  1184874 non-null  int64
#  7   submission_time           1184874 non-null  str
#  8   review_text               1183383 non-null  str
#  9   review_title              848473 non-null   str
#  10  skin_tone                 1002771 non-null  str
#  11  eye_color                 957915 non-null   str
#  12  skin_type                 1065457 non-null  str
# ...

# %%
products.isnull().sum()
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# size                  1631
# variation_type        1444
# variation_value       1598
# variation_desc        7244
# ingredients            945
# price_usd                0
# value_price_usd       8043
# sale_price_usd        8224
# limited_edition          0
# new                      0
# online_only              0
# out_of_stock             0
# sephora_exclusive        0
# highlights            2207
# primary_category         0
# secondary_category       8
# tertiary_category      990
# child_count              0
# child_max_price       5740
# child_min_price       5740
# dtype: int64

# %%
print(reviews.duplicated().sum())
duplicates = reviews[reviews.duplicated()]
# Out:
# 206880

# %%
df = reviews[~reviews.duplicated()]
df.shape
# Out:
# (977994, 18)

# %%
pd.set_option("display.max_columns", None)

# %%
d = df[df.duplicated(
    subset=["author_id", "review_text", 'review_title'], keep = False)
]
d
# Out:
#          author_id  rating  is_recommended  helpfulness  total_feedback_count  \
# 877    22934451719       5             1.0     1.000000                     2
# 878    22934451719       5             1.0     0.666667                     3
# 2136   33914299569       5             1.0     0.058823                    17
# 2137   33914299569       5             1.0     0.000000                    15
# 3854    1786504204       4             1.0          NaN                     0
# ...            ...     ...             ...          ...                   ...
# 48291   2153094181       4             1.0     0.764706                    34
# 48838   1288462295       5             1.0          NaN                     0
# 49398   1288462295       5             1.0     0.000000                     1
# 49425   8364661373       5             1.0     1.000000                     3
# 49946  21385610595       5             1.0          NaN                     0
#
# ...

# %%
data = df.drop_duplicates(
    subset=["author_id", "review_text", 'review_title'])
data.shape
# Out:
# (865433, 18)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
counts = data['rating'].value_counts()
sns.barplot(counts)
# Out:
# <Axes: xlabel='rating', ylabel='count'>

# %%
products['rating'].value_counts()
# Out:
# rating
# 5.0000    256
# 4.0000    174
# 4.5000     82
# 4.3333     68
# 3.0000     66
#          ...
# 4.2712      1
# 4.8403      1
# 4.7365      1
# 4.6214      1
# 4.6367      1
# Name: count, Length: 4394, dtype: int64

# %%
sns.boxplot(products['rating'])
# Out:
# <Axes: ylabel='rating'>

# %%
sns.histplot()
